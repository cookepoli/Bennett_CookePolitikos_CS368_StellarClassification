# %% [markdown]
# This notebook will show various pieces of qualitative (and some quantitative) information for each attribute that is worth studying within the data set.

# %% [markdown]
# Import dependencies.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Retrieve Data

# %%
df = pd.read_csv('preprocessed_data.csv')

df.head()
# Out:
#    Unnamed: 0       alpha      delta         u         g         r         i  \
# 0           0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573
# 1           1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812
# 2           2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857
# 3           3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454
# 4           4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711
#
#           z   class  redshift
# 0  18.79371  GALAXY  0.634794
# 1  21.61427  GALAXY  0.779136
# 2  18.94827  GALAXY  0.644195
# 3  19.25010  GALAXY  0.932346
# 4  15.54461  GALAXY  0.116123

# %% [markdown]
# We will use the attributes alpha, delta, u, g, r, i, z, and redshift.
# Let's remove what we don't need.

# %%
#df = df.drop(columns=['obj_ID', 'run_ID', 'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'plate', 'MJD', 'fiber_ID'])
#df.head()

# %% [markdown]
# Let's get the mean and standard deviation.

# %%
#df.std()

# %%
#df.mean()

# %% [markdown]
# And let's get histograms for each, to see the distribution of data.

# %%
df['alpha'].hist(bins = 20)
plt.show()

# %%
df['delta'].hist(bins = 20)
plt.show()

# %%
df['u'].hist(bins = 20)
plt.xlabel('u')
plt.ylabel('count')
plt.show()

# %%
df['g'].hist(bins = 20)
plt.xlabel('g')
plt.ylabel('count')
plt.show()

# %%
df['r'].hist(bins = 20)
plt.xlabel('r')
plt.ylabel('count')
plt.show()

# %%
df['i'].hist(bins = 20)
plt.xlabel('i')
plt.ylabel('count')
plt.show()

# %%
df['z'].hist(bins = 20)
plt.xlabel('z')
plt.ylabel('count')
plt.show()

# %%
df['redshift'].hist(bins = 20)
plt.xlabel('redshift')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Looks like we'll need to eliminate some outliers.
